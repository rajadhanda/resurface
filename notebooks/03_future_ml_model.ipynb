# %% [markdown]
# # Future ML Model
#
# This notebook is a placeholder for later work: turning features into an ML model.
#
# ## Ideas
#
# 1. **Feature Engineering**: Extract features from `Features` dataclass into a feature vector
# 2. **Model Training**: Train a classifier (e.g., Random Forest, XGBoost, or small neural network)
# 3. **Evaluation**: Compare ML model performance against heuristic classifier
# 4. **Deployment**: Export model for use in iOS/Android app
#
# ## Next Steps
#
# - Collect more labelled data
# - Experiment with different feature combinations
# - Try different model architectures
# - Optimize for mobile deployment (model size, inference speed)

# %%
# Placeholder for future ML model code
print("Future ML model implementation will go here")
